# %%
import numpy as np
import pandas as pd
import warnings 
warnings.filterwarnings("ignore")
import matplotlib.pyplot as  plt
import seaborn as sns

# %%
data = pd.read_csv( r"C:\Users\samar\OneDrive\Desktop\code\train_data1.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# X =data.iloc[:,[2,4,5]]
X = data[["Pclass","Sex","Age"]]
X
# Out:
#      Pclass     Sex   Age
# 0         3    male  22.0
# 1         1  female  38.0
# 2         3  female  26.0
# 3         1  female  35.0
# 4         3    male  35.0
# ..      ...     ...   ...
# 886       2    male  27.0
# 887       1  female  19.0
# 888       3  female  28.0
# 889       1    male  26.0
# 890       3    male  32.0
#
# [891 rows x 3 columns]

# %%
# y = data.iloc[:,1:2]
y = data["Survived"]
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X["Sex"] = le.fit_transform(X["Sex"])
X
# Out:
#      Pclass  Sex   Age
# 0         3    1  22.0
# 1         1    0  38.0
# 2         3    0  26.0
# 3         1    0  35.0
# 4         3    1  35.0
# ..      ...  ...   ...
# 886       2    1  27.0
# 887       1    0  19.0
# 888       3    0  28.0
# 889       1    1  26.0
# 890       3    1  32.0
#
# [891 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0 )

# %%
# X.iloc[:,4] = le.fit_transform(X.iloc[:,4])
# X.iloc[:, 4] = le.fit_transform(X.iloc[:, 4].values.reshape(-1, 1))

# %%
from lazypredict.Supervised import LazyClassifier
cls_1 = LazyClassifier()
models, predictions = cls_1.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 34.04it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# KNeighborsClassifier               0.85               0.83     0.83      0.85
# XGBClassifier                      0.83               0.82     0.82      0.83
# ExtraTreeClassifier                0.84               0.81     0.81      0.83
# ExtraTreesClassifier               0.83               0.81     0.81      0.83
# RandomForestClassifier             0.83               0.81     0.81      0.82
# DecisionTreeClassifier             0.82               0.80     0.80      0.82
# LGBMClassifier                     0.82               0.80     0.80      0.81
# AdaBoostClassifier                 0.80               0.80     0.80      0.81
# NearestCentroid                    0.79               0.80     0.80      0.80
# ...

# %%
# from xgboost import XGBClassifier
# cls= XGBClassifier()
# cls.fit(X_train, y_train)

# %%
from sklearn.neighbors import KNeighborsClassifier
# cl = KNeighborsClassifier(algorithm='brute', leaf_size=50, metric='minkowsk', n_neighbors=19, p=10, weights='distance')
cl = KNeighborsClassifier(n_neighbors=5, metric='minkowski', weights='distance',algorithm='brute')
# cl = KNeighborsClassifier()

# %%
cl.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='brute', weights='distance')

# %%
y_pred = cl.predict(X_test)
y_pred_1 = cl.predict(X_train)

# %%
from sklearn.metrics import accuracy_score
ac = accuracy_score(y_test,y_pred)
ac
# Out:
# 0.8100558659217877

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val = cross_val_score(cl,X,y,cv = 6).mean()

# %%
cross_val
# Out:
# 0.7957252554567992

# %%
train_accuracy = accuracy_score(y_train,y_pred_1)
train_accuracy
# Out:
# 0.8665730337078652

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[101,   9],
#        [ 25,  44]], dtype=int64)

# %%
# from sklearn.metrics import accuracy_score
# ac = accuracy_score(y_test,y_pred)
# ac

# %%
# bias = cls.fit(X_train,y_train)
# bias

# %%
# variance = cls.fit(y_test, y_train)
# variance

# %%
import pickle
pickle.dump(cls, open("Titanic.pkl", "wb"))

# %%
import os 
os.getcwd()
